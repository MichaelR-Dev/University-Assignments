# %%
#Dependencies

## PROJECT MODULES
### mongo.py - pyCRUSD MongoDB Class
import mongo

## EXTERNAL MODULES
## pprint - prettyprint for friendlier console outputs
from pprint import pprint

#Initialize Client
db_client = mongo.AnimalShelter()

#Document filter to be read
data = {
    "breed": "Pit Bull Mix"
}

pprint(db_client.read(data))
# Out:
# [{'_id': ObjectId('646a53745d655b9f97cf4bdf'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 106.662202380952,
#   'animal_id': 'A673830',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2012-03-03',
#   'datetime': '2014-03-19 15:15:00',
#   'location_lat': 30.2954256583441,
#   'location_long': -97.3136642110436,
#   'monthyear': '2014-03-19T15:15:00',
#   'name': '*Seth',
#   'outcome_subtype': 'Aggressive',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 7,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4be2'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 62.2464285714286,
#   'animal_id': 'A664843',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2013-06-09',
#   'datetime': '2014-08-18 17:24:00',
#   'location_lat': 30.4515549397366,
#   'location_long': -97.474104510925,
#   'monthyear': '2014-08-18T17:24:00',
#   'name': 'Sherlock',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 12,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4be5'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 198.820634920635,
#   'animal_id': 'A712638',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Red/White',
#   'date_of_birth': '2012-09-26',
#   'datetime': '2016-07-18 17:52:00',
#   'location_lat': 30.5798299207017,
#   'location_long': -97.5588487936533,
#   'monthyear': '2016-07-18T17:52:00',
#   'name': 'Marcus',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 15,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4be8'),
#   'age_upon_outcome': '6 months',
#   'age_upon_outcome_in_weeks': 28.3865079365079,
#   'animal_id': 'A668960',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-06-12',
#   'datetime': '2013-12-27 16:56:00',
#   'location_lat': 30.5943410758588,
#   'location_long': -97.2489933569515,
#   'monthyear': '2013-12-27T16:56:00',
#   'name': '*Gigi',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 17,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4bec'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.393948412698,
#   'animal_id': 'A730354',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-07-02',
#   'datetime': '2017-07-01 18:11:00',
#   'location_lat': 30.4815689674138,
#   'location_long': -97.3694960927915,
#   'monthyear': '2017-07-01T18:11:00',
#   'name': 'Mia',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 21,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4bf0'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 145.949007936508,
#   'animal_id': 'A692137',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-05-15',
#   'datetime': '2016-03-01 15:26:00',
#   'location_lat': 30.3691596527395,
#   'location_long': -97.3810871961031,
#   'monthyear': '2016-03-01T15:26:00',
#   'name': 'Shadow',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 23,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4bfb'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 69.2319444444445,
#   'animal_id': 'A743879',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2016-02-18',
#   'datetime': '2017-06-16 14:58:00',
#   'location_lat': 30.757367526077,
#   'location_long': -97.4667421648321,
#   'monthyear': '2017-06-16T14:58:00',
#   'name': '*Tallulah',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 28,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c02'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 110.655753968254,
#   'animal_id': 'A697233',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2013-02-20',
#   'datetime': '2015-04-05 14:10:00',
#   'location_lat': 30.3091899182072,
#   'location_long': -97.407391329783,
#   'monthyear': '2015-04-05T14:10:00',
#   'name': '*Tolliver',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 43,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c20'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 69.947123015873,
#   'animal_id': 'A690377',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2013-10-19',
#   'datetime': '2015-02-20 15:07:00',
#   'location_lat': 30.5804041697432,
#   'location_long': -97.3441305405284,
#   'monthyear': '2015-02-20T15:07:00',
#   'name': '*Pagani',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 78,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c34'),
#   'age_upon_outcome': '2 weeks',
#   'age_upon_outcome_in_weeks': 2.50386904761905,
#   'animal_id': 'A694902',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Tricolor',
#   'date_of_birth': '2014-12-22',
#   'datetime': '2015-01-08 12:39:00',
#   'location_lat': 30.650885495879,
#   'location_long': -97.4935832242768,
#   'monthyear': '2015-01-08T12:39:00',
#   'name': '',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 97,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c39'),
#   'age_upon_outcome': '4 months',
#   'age_upon_outcome_in_weeks': 18.3690476190476,
#   'animal_id': 'A664597',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-06-05',
#   'datetime': '2013-10-11 14:00:00',
#   'location_lat': 30.3562764370057,
#   'location_long': -97.3933441772883,
#   'monthyear': '2013-10-11T14:00:00',
#   'name': 'Phoebe',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 102,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c3c'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 109.400595238095,
#   'animal_id': 'A717889',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2013-12-17',
#   'datetime': '2016-01-21 19:18:00',
#   'location_lat': 30.3106480620317,
#   'location_long': -97.3209950362458,
#   'monthyear': '2016-01-21T19:18:00',
#   'name': 'Lulu',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 104,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c44'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 115.394146825397,
#   'animal_id': 'A725343',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2014-04-28',
#   'datetime': '2016-07-13 18:13:00',
#   'location_lat': 30.4283598669481,
#   'location_long': -97.3545862586938,
#   'monthyear': '2016-07-13T18:13:00',
#   'name': 'Luna',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 92,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c46'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 117.089880952381,
#   'animal_id': 'A718636',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2014-01-03',
#   'datetime': '2016-04-01 15:06:00',
#   'location_lat': 30.6606697753284,
#   'location_long': -97.6768318922385,
#   'monthyear': '2016-04-01T15:06:00',
#   'name': '*Hans Knut',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 117,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c4a'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 105.957043650794,
#   'animal_id': 'A723147',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/Black',
#   'date_of_birth': '2014-03-27',
#   'datetime': '2016-04-06 16:47:00',
#   'location_lat': 30.3283662523352,
#   'location_long': -97.3458945579974,
#   'monthyear': '2016-04-06T16:47:00',
#   'name': 'Major',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 116,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c51'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 83.3628968253968,
#   'animal_id': 'A669638',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2012-12-23',
#   'datetime': '2014-07-29 12:58:00',
#   'location_lat': 30.2793865920089,
#   'location_long': -97.3127575035961,
#   'monthyear': '2014-07-29T12:58:00',
#   'name': 'Rufus',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 123,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c54'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 110.391765873016,
#   'animal_id': 'A731542',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2014-07-23',
#   'datetime': '2016-09-02 17:49:00',
#   'location_lat': 30.5433475655082,
#   'location_long': -97.7398802569118,
#   'monthyear': '2016-09-02T17:49:00',
#   'name': 'Roscoe',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 128,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c66'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 187.935119047619,
#   'animal_id': 'A731736',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2013-07-26',
#   'datetime': '2017-03-02 13:06:00',
#   'location_lat': 30.2860110453244,
#   'location_long': -97.3974800649621,
#   'monthyear': '2017-03-02T13:06:00',
#   'name': 'Novah',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 134,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c74'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 148.502976190476,
#   'animal_id': 'A696155',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Red',
#   'date_of_birth': '2013-01-30',
#   'datetime': '2015-12-05 12:30:00',
#   'location_lat': 30.4738122017467,
#   'location_long': -97.7239313509781,
#   'monthyear': '2015-12-05T12:30:00',
#   'name': 'Brurdaoex',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 161,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c94'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 57.6771825396825,
#   'animal_id': 'A763060',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2016-12-02',
#   'datetime': '2018-01-09 17:46:00',
#   'location_lat': 30.3270551121256,
#   'location_long': -97.6846677015017,
#   'monthyear': '2018-01-09T17:46:00',
#   'name': '*Cambria',
#   'outcome_subtype': 'Foster',
#   'outcome_type': 'Adoption',
#   'rec_num': 195,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4c96'),
#   'age_upon_outcome': '2 months',
#   'age_upon_outcome_in_weeks': 9.51825396825397,
#   'animal_id': 'A728227',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown',
#   'date_of_birth': '2016-04-01',
#   'datetime': '2016-06-06 15:04:00',
#   'location_lat': 30.7293584939239,
#   'location_long': -97.6420311147876,
#   'monthyear': '2016-06-06T15:04:00',
#   'name': '',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 193,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ca5'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.2290674603175,
#   'animal_id': 'A762373',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/Black',
#   'date_of_birth': '2016-11-19',
#   'datetime': '2017-11-19 14:29:00',
#   'location_lat': 30.3623540304887,
#   'location_long': -97.2596542623425,
#   'monthyear': '2017-11-19T14:29:00',
#   'name': 'Tiny',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 208,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ca7'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 98.0834325396825,
#   'animal_id': 'A670923',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2012-03-22',
#   'datetime': '2014-02-06 14:01:00',
#   'location_lat': 30.738632382063,
#   'location_long': -97.6643567915547,
#   'monthyear': '2014-02-06T14:01:00',
#   'name': 'Kayna',
#   'outcome_subtype': 'Behavior',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 213,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cac'),
#   'age_upon_outcome': '2 months',
#   'age_upon_outcome_in_weeks': 11.6795634920635,
#   'animal_id': 'A687188',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2014-06-17',
#   'datetime': '2014-09-06 18:10:00',
#   'location_lat': 30.5375348136155,
#   'location_long': -97.5948201768564,
#   'monthyear': '2014-09-06T18:10:00',
#   'name': '*Miss Sally',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 218,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cc3'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 54.3878968253968,
#   'animal_id': 'A720018',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2015-02-01',
#   'datetime': '2016-02-16 17:10:00',
#   'location_lat': 30.7561854019926,
#   'location_long': -97.4582116491015,
#   'monthyear': '2016-02-16T17:10:00',
#   'name': 'Ripley',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 230,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cc8'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 105.675992063492,
#   'animal_id': 'A707614',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2013-07-15',
#   'datetime': '2015-07-24 17:34:00',
#   'location_lat': 30.633124786153,
#   'location_long': -97.5488475781402,
#   'monthyear': '2015-07-24T17:34:00',
#   'name': 'Cayenne',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 244,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cf1'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 59.6811507936508,
#   'animal_id': 'A712665',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Fawn/White',
#   'date_of_birth': '2014-09-26',
#   'datetime': '2015-11-17 18:26:00',
#   'location_lat': 30.4647189755225,
#   'location_long': -97.6901535084285,
#   'monthyear': '2015-11-17T18:26:00',
#   'name': '*Jack Nick',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 287,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cf4'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 259.23878968254,
#   'animal_id': 'A693283',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2012-12-05',
#   'datetime': '2017-11-23 16:07:00',
#   'location_lat': 30.2814700782166,
#   'location_long': -97.3839659324091,
#   'monthyear': '2017-11-23T16:07:00',
#   'name': 'Maximus',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 277,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4cf6'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 156.6375,
#   'animal_id': 'A705339',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2012-06-16',
#   'datetime': '2015-06-17 11:06:00',
#   'location_lat': 30.3838821498896,
#   'location_long': -97.6867721625993,
#   'monthyear': '2015-06-17T11:06:00',
#   'name': 'Queenie',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 288,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d0a'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 245.362896825397,
#   'animal_id': 'A641779',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2011-11-13',
#   'datetime': '2016-07-26 12:58:00',
#   'location_lat': 30.6851377580131,
#   'location_long': -97.4172402349298,
#   'monthyear': '2016-07-26T12:58:00',
#   'name': 'Tonii Yayo',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 296,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d0b'),
#   'age_upon_outcome': '8 months',
#   'age_upon_outcome_in_weeks': 35.0865079365079,
#   'animal_id': 'A719793',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Tan',
#   'date_of_birth': '2015-06-01',
#   'datetime': '2016-02-01 14:32:00',
#   'location_lat': 30.4990068827935,
#   'location_long': -97.4617128642409,
#   'monthyear': '2016-02-01T14:32:00',
#   'name': 'Cece',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 309,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d11'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 127.677777777778,
#   'animal_id': 'A755247',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2015-07-31',
#   'datetime': '2018-01-09 17:52:00',
#   'location_lat': 30.5795255304752,
#   'location_long': -97.5993822870862,
#   'monthyear': '2018-01-09T17:52:00',
#   'name': 'Dobie',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 319,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d14'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 223.092361111111,
#   'animal_id': 'A609335',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Tan',
#   'date_of_birth': '2009-09-07',
#   'datetime': '2013-12-16 15:31:00',
#   'location_lat': 30.6695702302852,
#   'location_long': -97.6415864674312,
#   'monthyear': '2013-12-16T15:31:00',
#   'name': '*Churley',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 321,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d16'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.813888888889,
#   'animal_id': 'A756323',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2015-08-17',
#   'datetime': '2017-08-19 16:44:00',
#   'location_lat': 30.3574332873318,
#   'location_long': -97.3992993858778,
#   'monthyear': '2017-08-19T16:44:00',
#   'name': 'Bongo',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 322,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d2e'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.5428571428571,
#   'animal_id': 'A734612',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2015-09-19',
#   'datetime': '2016-09-20 19:12:00',
#   'location_lat': 30.6279386446592,
#   'location_long': -97.4893658137887,
#   'monthyear': '2016-09-20T19:12:00',
#   'name': 'Beans',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 328,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d55'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 105.784126984127,
#   'animal_id': 'A715041',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Chocolate/White',
#   'date_of_birth': '2013-10-30',
#   'datetime': '2015-11-09 11:44:00',
#   'location_lat': 30.5471052207334,
#   'location_long': -97.6008366166395,
#   'monthyear': '2015-11-09T11:44:00',
#   'name': 'Coco',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 380,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d5a'),
#   'age_upon_outcome': '4 months',
#   'age_upon_outcome_in_weeks': 18.5392857142857,
#   'animal_id': 'A725727',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2016-01-02',
#   'datetime': '2016-05-10 18:36:00',
#   'location_lat': 30.499407901417,
#   'location_long': -97.5853283846211,
#   'monthyear': '2016-05-10T18:36:00',
#   'name': '*Lucinda',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 389,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d71'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 158.234226190476,
#   'animal_id': 'A718312',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2012-12-27',
#   'datetime': '2016-01-08 15:21:00',
#   'location_lat': 30.5339920390695,
#   'location_long': -97.274389794471,
#   'monthyear': '2016-01-08T15:21:00',
#   'name': 'Lucky',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 416,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d73'),
#   'age_upon_outcome': '1 month',
#   'age_upon_outcome_in_weeks': 8.78174603174603,
#   'animal_id': 'A707206',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2015-05-13',
#   'datetime': '2015-07-13 11:20:00',
#   'location_lat': 30.6756928290313,
#   'location_long': -97.5577851746644,
#   'monthyear': '2015-07-13T11:20:00',
#   'name': '',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 410,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d79'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 235.68373015873,
#   'animal_id': 'A621716',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Chocolate/White',
#   'date_of_birth': '2010-03-11',
#   'datetime': '2014-09-15 18:52:00',
#   'location_lat': 30.3925545458195,
#   'location_long': -97.3224274291506,
#   'monthyear': '2014-09-15T18:52:00',
#   'name': '*Maizy',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 422,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d7d'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 78.6748015873016,
#   'animal_id': 'A694186',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-06-22',
#   'datetime': '2014-12-24 17:22:00',
#   'location_lat': 30.5959040011866,
#   'location_long': -97.3238493835232,
#   'monthyear': '2014-12-24T17:22:00',
#   'name': 'Fossa',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 405,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d87'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 83.3766865079365,
#   'animal_id': 'A666852',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Chocolate/White',
#   'date_of_birth': '2012-05-08',
#   'datetime': '2013-12-12 15:17:00',
#   'location_lat': 30.7120125379155,
#   'location_long': -97.5229495825491,
#   'monthyear': '2013-12-12T15:17:00',
#   'name': '*Bonnie',
#   'outcome_subtype': 'Aggressive',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 430,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d89'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 156.942956349206,
#   'animal_id': 'A759045',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Tan',
#   'date_of_birth': '2014-09-25',
#   'datetime': '2017-09-27 14:25:00',
#   'location_lat': 30.5335845440854,
#   'location_long': -97.6232006232885,
#   'monthyear': '2017-09-27T14:25:00',
#   'name': 'Boss',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 433,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d93'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 222.110515873016,
#   'animal_id': 'A657492',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2010-06-28',
#   'datetime': '2014-09-29 18:34:00',
#   'location_lat': 30.631803543411,
#   'location_long': -97.3524892412922,
#   'monthyear': '2014-09-29T18:34:00',
#   'name': 'Freckles',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 449,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d9b'),
#   'age_upon_outcome': '6 years',
#   'age_upon_outcome_in_weeks': 318.791468253968,
#   'animal_id': 'A730511',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Brown',
#   'date_of_birth': '2010-10-22',
#   'datetime': '2016-11-30 12:58:00',
#   'location_lat': 30.471181941333,
#   'location_long': -97.2858124185314,
#   'monthyear': '2016-11-30T12:58:00',
#   'name': 'Rocky',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 457,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4d9f'),
#   'age_upon_outcome': '3 months',
#   'age_upon_outcome_in_weeks': 13.6766865079365,
#   'animal_id': 'A722347',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2015-12-15',
#   'datetime': '2016-03-19 17:41:00',
#   'location_lat': 30.3516055793832,
#   'location_long': -97.5567555139586,
#   'monthyear': '2016-03-19T17:41:00',
#   'name': '',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 461,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4da5'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 53.1037698412698,
#   'animal_id': 'A722331',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2015-03-14',
#   'datetime': '2016-03-19 17:26:00',
#   'location_lat': 30.7345213672016,
#   'location_long': -97.2648050194129,
#   'monthyear': '2016-03-19T17:26:00',
#   'name': '*Hendrix',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 464,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4dbe'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 209.239682539683,
#   'animal_id': 'A696188',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2011-01-30',
#   'datetime': '2015-02-02 16:16:00',
#   'location_lat': 30.291593037412,
#   'location_long': -97.5643350088454,
#   'monthyear': '2015-02-02T16:16:00',
#   'name': 'Maya',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 485,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4dc5'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 56.3828373015873,
#   'animal_id': 'A694430',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown',
#   'date_of_birth': '2013-12-28',
#   'datetime': '2015-01-26 16:19:00',
#   'location_lat': 30.2804584225439,
#   'location_long': -97.325423639897,
#   'monthyear': '2015-01-26T16:19:00',
#   'name': 'Chica',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 499,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4dd8'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 117.965575396825,
#   'animal_id': 'A717102',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-12-02',
#   'datetime': '2016-03-06 18:13:00',
#   'location_lat': 30.4130389062341,
#   'location_long': -97.4169907799678,
#   'monthyear': '2016-03-06T18:13:00',
#   'name': '*Rufus',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 519,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4de1'),
#   'age_upon_outcome': '8 months',
#   'age_upon_outcome_in_weeks': 35.8228174603175,
#   'animal_id': 'A695920',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2014-05-25',
#   'datetime': '2015-01-30 18:14:00',
#   'location_lat': 30.6279102398991,
#   'location_long': -97.2512278534435,
#   'monthyear': '2015-01-30T18:14:00',
#   'name': '*Wanda',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 528,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4de5'),
#   'age_upon_outcome': '6 years',
#   'age_upon_outcome_in_weeks': 314.654861111111,
#   'animal_id': 'A765126',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2012-01-13',
#   'datetime': '2018-01-23 14:01:00',
#   'location_lat': 30.6541530934726,
#   'location_long': -97.5427105137445,
#   'monthyear': '2018-01-23T14:01:00',
#   'name': '*Dottie',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 532,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4de9'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 151.522420634921,
#   'animal_id': 'A664812',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2011-04-12',
#   'datetime': '2014-03-07 15:46:00',
#   'location_lat': 30.5371162804814,
#   'location_long': -97.4104975020292,
#   'monthyear': '2014-03-07T15:46:00',
#   'name': 'Blue',
#   'outcome_subtype': 'Aggressive',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 535,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e00'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 135.934126984127,
#   'animal_id': 'A752579',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-06-24',
#   'datetime': '2018-01-30 12:56:00',
#   'location_lat': 30.7429753064713,
#   'location_long': -97.4887995883101,
#   'monthyear': '2018-01-30T12:56:00',
#   'name': 'Faneto',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 559,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e09'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 164.21755952381,
#   'animal_id': 'A647338',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Red',
#   'date_of_birth': '2012-08-08',
#   'datetime': '2015-10-01 12:33:00',
#   'location_lat': 30.465575119188,
#   'location_long': -97.5756570926444,
#   'monthyear': '2015-10-01T12:33:00',
#   'name': 'Pinocchio',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 568,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e0d'),
#   'age_upon_outcome': '2 months',
#   'age_upon_outcome_in_weeks': 9.09414682539682,
#   'animal_id': 'A714104',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown',
#   'date_of_birth': '2015-08-18',
#   'datetime': '2015-10-20 15:49:00',
#   'location_lat': 30.3553228281969,
#   'location_long': -97.5259949912361,
#   'monthyear': '2015-10-20T15:49:00',
#   'name': '*Paisley',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 571,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e10'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 109.240674603175,
#   'animal_id': 'A671931',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2012-02-01',
#   'datetime': '2014-03-06 16:26:00',
#   'location_lat': 30.4411955020016,
#   'location_long': -97.6293118977272,
#   'monthyear': '2014-03-06T16:26:00',
#   'name': '*Sophia',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 574,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e1b'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 66.1130952380952,
#   'animal_id': 'A740698',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2016-03-21',
#   'datetime': '2017-06-26 19:00:00',
#   'location_lat': 30.340724591939,
#   'location_long': -97.3801798045731,
#   'monthyear': '2017-06-26T19:00:00',
#   'name': 'Biggie',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 579,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e38'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 158.39255952381,
#   'animal_id': 'A742892',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black',
#   'date_of_birth': '2014-01-30',
#   'datetime': '2017-02-11 17:57:00',
#   'location_lat': 30.7670340661898,
#   'location_long': -97.4246125958373,
#   'monthyear': '2017-02-11T17:57:00',
#   'name': '*Finch',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 615,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e3a'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 165.93253968254,
#   'animal_id': 'A670407',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2011-01-07',
#   'datetime': '2014-03-13 12:40:00',
#   'location_lat': 30.5882460271183,
#   'location_long': -97.3100179144126,
#   'monthyear': '2014-03-13T12:40:00',
#   'name': 'Buster',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 617,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e56'),
#   'age_upon_outcome': '5 years',
#   'age_upon_outcome_in_weeks': 261.105853174603,
#   'animal_id': 'A729736',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2011-06-23',
#   'datetime': '2016-06-23 17:47:00',
#   'location_lat': 30.3937871425988,
#   'location_long': -97.3286479726413,
#   'monthyear': '2016-06-23T17:47:00',
#   'name': 'Jake',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 628,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e57'),
#   'age_upon_outcome': '5 months',
#   'age_upon_outcome_in_weeks': 25.6977182539683,
#   'animal_id': 'A762680',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2017-06-24',
#   'datetime': '2017-12-20 21:13:00',
#   'location_lat': 30.4098348401312,
#   'location_long': -97.2576831385456,
#   'monthyear': '2017-12-20T21:13:00',
#   'name': '*Benny',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 640,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4e7c'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 110.63869047619,
#   'animal_id': 'A681187',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black Brindle/White',
#   'date_of_birth': '2012-06-13',
#   'datetime': '2014-07-27 11:18:00',
#   'location_lat': 30.4705198877223,
#   'location_long': -97.4903083238003,
#   'monthyear': '2014-07-27T11:18:00',
#   'name': '*Dalton',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 661,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ea6'),
#   'age_upon_outcome': '7 months',
#   'age_upon_outcome_in_weeks': 31.9454365079365,
#   'animal_id': 'A725530',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2015-10-30',
#   'datetime': '2016-06-09 14:50:00',
#   'location_lat': 30.3055255064021,
#   'location_long': -97.3713962551111,
#   'monthyear': '2016-06-09T14:50:00',
#   'name': 'King',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 721,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ed5'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 233.946626984127,
#   'animal_id': 'A684222',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2011-07-21',
#   'datetime': '2016-01-13 15:02:00',
#   'location_lat': 30.6840111142052,
#   'location_long': -97.263518361294,
#   'monthyear': '2016-01-13T15:02:00',
#   'name': 'Brownie',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 772,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ed6'),
#   'age_upon_outcome': '6 months',
#   'age_upon_outcome_in_weeks': 26.8159722222222,
#   'animal_id': 'A676510',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2013-10-11',
#   'datetime': '2014-04-16 17:05:00',
#   'location_lat': 30.7476238032631,
#   'location_long': -97.6399390038888,
#   'monthyear': '2014-04-16T17:05:00',
#   'name': '',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 773,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ede'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 112.220932539683,
#   'animal_id': 'A705299',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-06-15',
#   'datetime': '2015-08-09 13:07:00',
#   'location_lat': 30.3578575813747,
#   'location_long': -97.703431407006,
#   'monthyear': '2015-08-09T13:07:00',
#   'name': 'Dexter',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 780,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ee6'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.822420634921,
#   'animal_id': 'A741404',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-01-01',
#   'datetime': '2017-01-03 18:10:00',
#   'location_lat': 30.7626375117111,
#   'location_long': -97.532347766435,
#   'monthyear': '2017-01-03T18:10:00',
#   'name': 'Squishy',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 762,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ee9'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.6830357142857,
#   'animal_id': 'A693856',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/Tan',
#   'date_of_birth': '2013-12-15',
#   'datetime': '2014-12-18 18:45:00',
#   'location_lat': 30.3185575642225,
#   'location_long': -97.5444828842699,
#   'monthyear': '2014-12-18T18:45:00',
#   'name': 'Jizzle',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 763,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4ef1'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 130.803273809524,
#   'animal_id': 'A750191',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2015-05-24',
#   'datetime': '2017-11-24 14:57:00',
#   'location_lat': 30.6309485056866,
#   'location_long': -97.6395652783914,
#   'monthyear': '2017-11-24T14:57:00',
#   'name': '*Sheba',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 797,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f03'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.525496031746,
#   'animal_id': 'A724642',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue',
#   'date_of_birth': '2015-04-19',
#   'datetime': '2016-04-20 16:17:00',
#   'location_lat': 30.5777069557996,
#   'location_long': -97.3375825857152,
#   'monthyear': '2016-04-20T16:17:00',
#   'name': 'Chief',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 811,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f0f'),
#   'age_upon_outcome': '10 months',
#   'age_upon_outcome_in_weeks': 44.3759920634921,
#   'animal_id': 'A719736',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-03-26',
#   'datetime': '2016-01-30 15:10:00',
#   'location_lat': 30.6759953518566,
#   'location_long': -97.3813214951754,
#   'monthyear': '2016-01-30T15:10:00',
#   'name': 'Bevo',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 829,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f14'),
#   'age_upon_outcome': '6 years',
#   'age_upon_outcome_in_weeks': 316.675892857143,
#   'animal_id': 'A623561',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2009-04-03',
#   'datetime': '2015-04-28 17:33:00',
#   'location_lat': 30.5105357929205,
#   'location_long': -97.2878342938612,
#   'monthyear': '2015-04-28T17:33:00',
#   'name': 'Marley',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 818,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f16'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.52123015873,
#   'animal_id': 'A750925',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue',
#   'date_of_birth': '2015-06-02',
#   'datetime': '2017-06-02 15:34:00',
#   'location_lat': 30.5169312220812,
#   'location_long': -97.580530271038,
#   'monthyear': '2017-06-02T15:34:00',
#   'name': '',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 816,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f1f'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.386408730159,
#   'animal_id': 'A716891',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2013-11-27',
#   'datetime': '2015-11-27 16:55:00',
#   'location_lat': 30.3986675790287,
#   'location_long': -97.2954245588649,
#   'monthyear': '2015-11-27T16:55:00',
#   'name': 'Nala',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 846,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f28'),
#   'age_upon_outcome': '3 months',
#   'age_upon_outcome_in_weeks': 13.827380952381,
#   'animal_id': 'A735834',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2016-06-30',
#   'datetime': '2016-10-04 19:00:00',
#   'location_lat': 30.6031131780923,
#   'location_long': -97.4073401846239,
#   'monthyear': '2016-10-04T19:00:00',
#   'name': '',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 852,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f2b'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.649603174603,
#   'animal_id': 'A735889',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2014-10-01',
#   'datetime': '2016-10-02 13:08:00',
#   'location_lat': 30.7644617904823,
#   'location_long': -97.7068745843438,
#   'monthyear': '2016-10-02T13:08:00',
#   'name': '',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 837,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f30'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 68.1110119047619,
#   'animal_id': 'A757808',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue',
#   'date_of_birth': '2016-09-07',
#   'datetime': '2017-12-27 18:39:00',
#   'location_lat': 30.356095589896,
#   'location_long': -97.5164067193174,
#   'monthyear': '2017-12-27T18:39:00',
#   'name': 'Peter',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 854,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f36'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 114.36369047619,
#   'animal_id': 'A755213',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-07-31',
#   'datetime': '2017-10-08 13:06:00',
#   'location_lat': 30.3422258608453,
#   'location_long': -97.5296877830546,
#   'monthyear': '2017-10-08T13:06:00',
#   'name': 'Jinx',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 863,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f4c'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 75.3945436507937,
#   'animal_id': 'A761409',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2015-11-04',
#   'datetime': '2017-04-14 18:17:00',
#   'location_lat': 30.7466727300209,
#   'location_long': -97.6147377131039,
#   'monthyear': '2017-04-14T18:17:00',
#   'name': 'Buster',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 891,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f53'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.8172619047619,
#   'animal_id': 'A749325',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown',
#   'date_of_birth': '2016-05-13',
#   'datetime': '2017-05-17 17:18:00',
#   'location_lat': 30.3203252407429,
#   'location_long': -97.5320752106758,
#   'monthyear': '2017-05-17T17:18:00',
#   'name': 'Gisele',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 896,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f8d'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 106.09623015873,
#   'animal_id': 'A669859',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Red/White',
#   'date_of_birth': '2011-12-28',
#   'datetime': '2014-01-08 16:10:00',
#   'location_lat': 30.3068810405226,
#   'location_long': -97.4080254946,
#   'monthyear': '2014-01-08T16:10:00',
#   'name': '*Mack',
#   'outcome_subtype': 'Behavior',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 951,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f92'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 52.8167658730159,
#   'animal_id': 'A727627',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2015-05-23',
#   'datetime': '2016-05-26 17:13:00',
#   'location_lat': 30.4599853306743,
#   'location_long': -97.6443001546578,
#   'monthyear': '2016-05-26T17:13:00',
#   'name': 'Cesar',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 952,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f94'),
#   'age_upon_outcome': '5 years',
#   'age_upon_outcome_in_weeks': 294.20248015873,
#   'animal_id': 'A701495',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2010-04-30',
#   'datetime': '2015-12-19 10:01:00',
#   'location_lat': 30.2695466477852,
#   'location_long': -97.6998513084862,
#   'monthyear': '2015-12-19T10:01:00',
#   'name': 'Bella',
#   'outcome_subtype': 'Foster',
#   'outcome_type': 'Adoption',
#   'rec_num': 959,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f96'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 78.250496031746,
#   'animal_id': 'A686300',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Chocolate',
#   'date_of_birth': '2013-02-20',
#   'datetime': '2014-08-21 18:05:00',
#   'location_lat': 30.580104596559,
#   'location_long': -97.4986966827011,
#   'monthyear': '2014-08-21T18:05:00',
#   'name': 'Titus',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 956,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f97'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 94.5025793650794,
#   'animal_id': 'A624126',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue Tiger/White',
#   'date_of_birth': '2012-01-28',
#   'datetime': '2013-11-19 12:26:00',
#   'location_lat': 30.4254948103172,
#   'location_long': -97.5593759677569,
#   'monthyear': '2013-11-19T12:26:00',
#   'name': 'Blue',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 955,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53745d655b9f97cf4f9d'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 56.5191468253968,
#   'animal_id': 'A718864',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2015-01-08',
#   'datetime': '2016-02-07 15:13:00',
#   'location_lat': 30.4585050473467,
#   'location_long': -97.36401796727,
#   'monthyear': '2016-02-07T15:13:00',
#   'name': '*Wilma',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 965,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53745d655b9f97cf4fa1'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 196.663392857143,
# ...
#  {'_id': ObjectId('646a53755d655b9f97cf71a1'),
#   'age_upon_outcome': '6 years',
#   'age_upon_outcome_in_weeks': 354.077876984127,
#   'animal_id': 'A678839',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2010-05-13',
#   'datetime': '2017-02-23 13:05:00',
#   'location_lat': 30.7160048940882,
#   'location_long': -97.5844225244925,
#   'monthyear': '2017-02-23T13:05:00',
#   'name': 'Frida',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 9665,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf71a8'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 114.515674603175,
#   'animal_id': 'A730350',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2014-07-02',
#   'datetime': '2016-09-10 14:38:00',
#   'location_lat': 30.7595461258944,
#   'location_long': -97.3197526957058,
#   'monthyear': '2016-09-10T14:38:00',
#   'name': '*Caleb',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9687,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf71ae'),
#   'age_upon_outcome': '3 weeks',
#   'age_upon_outcome_in_weeks': 3.51349206349206,
#   'animal_id': 'A708528',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2015-07-07',
#   'datetime': '2015-07-31 14:16:00',
#   'location_lat': 30.5220718507105,
#   'location_long': -97.4380926437006,
#   'monthyear': '2015-07-31T14:16:00',
#   'name': '',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 9684,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf71d3'),
#   'age_upon_outcome': '7 years',
#   'age_upon_outcome_in_weeks': 368.505357142857,
#   'animal_id': 'A689036',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2007-09-28',
#   'datetime': '2014-10-20 12:54:00',
#   'location_lat': 30.6771314644213,
#   'location_long': -97.5492918140944,
#   'monthyear': '2014-10-20T12:54:00',
#   'name': 'Little Dude',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9730,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf71d4'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 120.790178571429,
#   'animal_id': 'A678433',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue',
#   'date_of_birth': '2012-05-09',
#   'datetime': '2014-09-01 12:45:00',
#   'location_lat': 30.7138290062025,
#   'location_long': -97.4660259398569,
#   'monthyear': '2014-09-01T12:45:00',
#   'name': 'Roscoe',
#   'outcome_subtype': 'Aggressive',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 9731,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7205'),
#   'age_upon_outcome': '6 months',
#   'age_upon_outcome_in_weeks': 26.3953373015873,
#   'animal_id': 'A737021',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black',
#   'date_of_birth': '2016-04-21',
#   'datetime': '2016-10-22 18:25:00',
#   'location_lat': 30.4062800025896,
#   'location_long': -97.4639955724003,
#   'monthyear': '2016-10-22T18:25:00',
#   'name': '',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 9764,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7206'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 217.507837301587,
#   'animal_id': 'A703649',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Brown',
#   'date_of_birth': '2012-05-27',
#   'datetime': '2016-07-27 13:19:00',
#   'location_lat': 30.384328730755,
#   'location_long': -97.4470529599432,
#   'monthyear': '2016-07-27T13:19:00',
#   'name': '*Kismet',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9774,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf7231'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.623511904762,
#   'animal_id': 'A684265',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2012-07-21',
#   'datetime': '2014-07-23 08:45:00',
#   'location_lat': 30.5532861425092,
#   'location_long': -97.3446229625899,
#   'monthyear': '2014-07-23T08:45:00',
#   'name': 'Heartbreaker',
#   'outcome_subtype': 'Aggressive',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 9817,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7248'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 86.6625,
#   'animal_id': 'A687043',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Tan',
#   'date_of_birth': '2014-03-02',
#   'datetime': '2015-10-29 15:18:00',
#   'location_lat': 30.6734235520326,
#   'location_long': -97.6124292443816,
#   'monthyear': '2015-10-29T15:18:00',
#   'name': 'Austin',
#   'outcome_subtype': 'Foster',
#   'outcome_type': 'Adoption',
#   'rec_num': 9836,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7249'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 137.953670634921,
#   'animal_id': 'A743467',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2014-06-22',
#   'datetime': '2017-02-11 16:13:00',
#   'location_lat': 30.3704562523619,
#   'location_long': -97.3583026159231,
#   'monthyear': '2017-02-11T16:13:00',
#   'name': 'Eva',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9837,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf724a'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 79.3548611111111,
#   'animal_id': 'A723770',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White',
#   'date_of_birth': '2014-10-08',
#   'datetime': '2016-04-15 11:37:00',
#   'location_lat': 30.4985224686102,
#   'location_long': -97.4918000430868,
#   'monthyear': '2016-04-15T11:37:00',
#   'name': 'Red',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9841,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf724f'),
#   'age_upon_outcome': '10 months',
#   'age_upon_outcome_in_weeks': 45.0732142857143,
#   'animal_id': 'A695602',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2014-03-18',
#   'datetime': '2015-01-27 12:18:00',
#   'location_lat': 30.3282434646371,
#   'location_long': -97.2953290778862,
#   'monthyear': '2015-01-27T12:18:00',
#   'name': 'Cinnamon',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 9853,
#   'sex_upon_outcome': 'Intact Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf7259'),
#   'age_upon_outcome': '1 month',
#   'age_upon_outcome_in_weeks': 7.82410714285714,
#   'animal_id': 'A742456',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/Black',
#   'date_of_birth': '2016-12-22',
#   'datetime': '2017-02-14 18:27:00',
#   'location_lat': 30.3087603390228,
#   'location_long': -97.7050094796261,
#   'monthyear': '2017-02-14T18:27:00',
#   'name': '*Arrow',
#   'outcome_subtype': 'Foster',
#   'outcome_type': 'Adoption',
#   'rec_num': 9848,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf725c'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 53.1010912698413,
#   'animal_id': 'A743234',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2016-02-06',
#   'datetime': '2017-02-11 16:59:00',
#   'location_lat': 30.6724158760749,
#   'location_long': -97.459046541479,
#   'monthyear': '2017-02-11T16:59:00',
#   'name': 'Bear',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9865,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7262'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 137.222420634921,
#   'animal_id': 'A704910',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue',
#   'date_of_birth': '2013-02-01',
#   'datetime': '2015-09-19 13:22:00',
#   'location_lat': 30.7282400601518,
#   'location_long': -97.3125569131309,
#   'monthyear': '2015-09-19T13:22:00',
#   'name': 'Precious',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9868,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf7264'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 104.686805555556,
#   'animal_id': 'A726184',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2014-05-07',
#   'datetime': '2016-05-08 19:23:00',
#   'location_lat': 30.4153866559081,
#   'location_long': -97.7051636160326,
#   'monthyear': '2016-05-08T19:23:00',
#   'name': 'Rudy',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9875,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7268'),
#   'age_upon_outcome': '5 months',
#   'age_upon_outcome_in_weeks': 22.2491071428571,
#   'animal_id': 'A750255',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2016-12-25',
#   'datetime': '2017-05-29 17:51:00',
#   'location_lat': 30.4696648136328,
#   'location_long': -97.7006230600947,
#   'monthyear': '2017-05-29T17:51:00',
#   'name': '*Bella',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9879,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf7269'),
#   'age_upon_outcome': '5 years',
#   'age_upon_outcome_in_weeks': 267.714285714286,
#   'animal_id': 'A706822',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown',
#   'date_of_birth': '2011-04-04',
#   'datetime': '2016-05-21 00:00:00',
#   'location_lat': 30.6873389467276,
#   'location_long': -97.5412015813249,
#   'monthyear': '2016-05-21T00:00:00',
#   'name': 'Bella',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 9870,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646a53755d655b9f97cf726e'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 86.7036706349206,
#   'animal_id': 'A730415',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle/White',
#   'date_of_birth': '2015-01-04',
#   'datetime': '2016-09-01 22:13:00',
#   'location_lat': 30.7269694509013,
#   'location_long': -97.34865011112,
#   'monthyear': '2016-09-01T22:13:00',
#   'name': 'Jake',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9882,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7271'),
#   'age_upon_outcome': '4 years',
#   'age_upon_outcome_in_weeks': 219.091765873016,
#   'animal_id': 'A677333',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2012-04-23',
#   'datetime': '2016-07-04 15:25:00',
#   'location_lat': 30.6023142695236,
#   'location_long': -97.637650924729,
#   'monthyear': '2016-07-04T15:25:00',
#   'name': 'Plex',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9869,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7272'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 166.676587301587,
#   'animal_id': 'A711740',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2012-09-11',
#   'datetime': '2015-11-21 17:40:00',
#   'location_lat': 30.431541558743,
#   'location_long': -97.3820124279193,
#   'monthyear': '2015-11-21T17:40:00',
#   'name': '*Sylvan',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9885,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7291'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 170.096726190476,
#   'animal_id': 'A725528',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'White/Black',
#   'date_of_birth': '2013-04-30',
#   'datetime': '2016-08-02 16:15:00',
#   'location_lat': 30.5920806262896,
#   'location_long': -97.6452597517446,
#   'monthyear': '2016-08-02T16:15:00',
#   'name': 'Loki',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9901,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf7294'),
#   'age_upon_outcome': '3 years',
#   'age_upon_outcome_in_weeks': 171.926587301587,
#   'animal_id': 'A666380',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown/White',
#   'date_of_birth': '2010-07-17',
#   'datetime': '2013-11-01 11:40:00',
#   'location_lat': 30.5713661792313,
#   'location_long': -97.4421505020515,
#   'monthyear': '2013-11-01T11:40:00',
#   'name': 'Bud',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9917,
#   'sex_upon_outcome': 'Intact Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf72b1'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 55.5136904761905,
#   'animal_id': 'A688115',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Blue/White',
#   'date_of_birth': '2013-09-14',
#   'datetime': '2014-10-07 14:18:00',
#   'location_lat': 30.5861903936877,
#   'location_long': -97.3362506430305,
#   'monthyear': '2014-10-07T14:18:00',
#   'name': 'Duke',
#   'outcome_subtype': 'Rabies Risk',
#   'outcome_type': 'Euthanasia',
#   'rec_num': 9942,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf72b7'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 110.953670634921,
#   'animal_id': 'A740334',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Brown Brindle',
#   'date_of_birth': '2014-12-15',
#   'datetime': '2017-01-29 16:13:00',
#   'location_lat': 30.3454168149407,
#   'location_long': -97.272759363398,
#   'monthyear': '2017-01-29T16:13:00',
#   'name': '*Baxter',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9953,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf72c4'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 53.3825396825397,
#   'animal_id': 'A669638',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2012-12-23',
#   'datetime': '2013-12-31 16:16:00',
#   'location_lat': 30.4576231578735,
#   'location_long': -97.586634428602,
#   'monthyear': '2013-12-31T16:16:00',
#   'name': 'Rufus',
#   'outcome_subtype': '',
#   'outcome_type': 'Return to Owner',
#   'rec_num': 9965,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646a53755d655b9f97cf72d4'),
#   'age_upon_outcome': '1 year',
#   'age_upon_outcome_in_weeks': 85.8124007936508,
#   'animal_id': 'A728197',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Tan/White',
#   'date_of_birth': '2014-12-01',
#   'datetime': '2016-07-23 16:29:00',
#   'location_lat': 30.7132928472422,
#   'location_long': -97.2894799321767,
#   'monthyear': '2016-07-23T16:29:00',
#   'name': '*Lady',
#   'outcome_subtype': '',
#   'outcome_type': 'Adoption',
#   'rec_num': 9986,
#   'sex_upon_outcome': 'Spayed Female'},
#  {'_id': ObjectId('646d4c13c0346ef61a2572d2'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 106.662202380952,
#   'animal_id': 'A6738301',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2017-03-03',
#   'datetime': '2023-03-19 15:15:00',
#   'location_lat': 30.2954256583441,
#   'location_long': -97.3136642110436,
#   'monthyear': '2023-03-19T15:15:00',
#   'name': 'Bartholomew',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 7,
#   'sex_upon_outcome': 'Neutered Male'},
#  {'_id': ObjectId('646d4c1fc0346ef61a2572d3'),
#   'age_upon_outcome': '2 years',
#   'age_upon_outcome_in_weeks': 106.662202380952,
#   'animal_id': 'A6738301',
#   'animal_type': 'Dog',
#   'breed': 'Pit Bull Mix',
#   'color': 'Black/White',
#   'date_of_birth': '2017-03-03',
#   'datetime': '2023-03-19 15:15:00',
#   'location_lat': 30.2954256583441,
#   'location_long': -97.3136642110436,
#   'monthyear': '2023-03-19T15:15:00',
#   'name': 'Bartholomew',
#   'outcome_subtype': 'Partner',
#   'outcome_type': 'Transfer',
#   'rec_num': 7,
#   'sex_upon_outcome': 'Neutered Male'}]
